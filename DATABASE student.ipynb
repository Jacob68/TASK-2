# %%
# !pip install dnspython
# !pip install pymongo[srv]

# %%
import json
import datetime
import pymongo
from pymongo import MongoClient
from pymongo import InsertOne
uri ='mongodb+srv://achu:123qwe@cluster0.uzirv.mongodb.net/myFirstDatabase?retryWrites=true&w=majority'
client=MongoClient(uri)
db = client.student
records = db.student
records.count_documents({})
# Out:
# 200

# %%
## DATA BASE OF ALL STUDENTS
x = []
for x in records.find():
    print(x)
# Out:
# {'_id': 0, 'name': 'aimee Zank', 'scores': [{'score': 1.463179736705023, 'type': 'exam'}, {'score': 11.78273309957772, 'type': 'quiz'}, {'score': 35.8740349954354, 'type': 'homework'}]}
# {'_id': 10, 'name': 'Denisha Cast', 'scores': [{'score': 45.61876862259409, 'type': 'exam'}, {'score': 98.35723209418343, 'type': 'quiz'}, {'score': 55.90835657173456, 'type': 'homework'}]}
# {'_id': 2, 'name': 'Corliss Zuk', 'scores': [{'score': 67.03077096065002, 'type': 'exam'}, {'score': 6.301851677835235, 'type': 'quiz'}, {'score': 66.28344683278382, 'type': 'homework'}]}
# {'_id': 4, 'name': 'Zachary Langlais', 'scores': [{'score': 78.68385091304332, 'type': 'exam'}, {'score': 90.2963101368042, 'type': 'quiz'}, {'score': 34.41620148042529, 'type': 'homework'}]}
# {'_id': 6, 'name': 'Jenette Flanders', 'scores': [{'score': 37.32285459166097, 'type': 'exam'}, {'score': 28.32634976913737, 'type': 'quiz'}, {'score': 81.57115318686338, 'type': 'homework'}]}
# ...

# %%
## QUSTION 1 : LEAD SCORRER IN ALL SEGMENTS COMBAINED WITH TOTAL MARKS 
D=[]
F = 0
C= []
K2 = []
for x in records.find({},{"_id":0, "name":1}):
  K2.append(x["name"])
for x in records.find({},{"_id":0, "scores":1}):
  for i in range(3):
    D.append(x["scores"][i]["score"])
  for i in range(3):
    F += D[i]
  C.append(F)
  D = []
  F = 0
for x in records.find({},{"_id":0, "name":1}):
  K2.append(x["name"])
print("The maximum total score is:",max(C),"AND The lead scorer in all exam combained:",K2[C.index(max(C))])
# Out:
# The maximum total score is: 275.94947751518237 AND The lead scorer in all exam combained: Jessika Dagenais

# %%
#TOP MARK IN EACH SEGMENT ALONG WITH TOPPER NAME
import numpy as np
x=records.aggregate([{'$unwind': '$scores'} ,{'$group': {'_id':{'type' : "$scores.type" },  'Max_score':{'$max':"$scores.score"}}}])
for i in x:
  print(i)
myquerry={'scores':{'score': 99.33685767140612, 'type': 'exam'}}
y=records.find(myquerry,{'_id':1,'name':1})
print("The student who scored maximum socre in exam:")
for i in y:
  print(i)
myquerry={'scores':{'score': 99.77237745070993, 'type': 'homework'}}
y=records.find(myquerry,{'_id':2,'name':2})
print("The student who scored maximum socre in homework:")
for i in y:
  print(i)
myquerry={'scores':{'score': 99.80348240553108, 'type': 'quiz'}}
y=records.find(myquerry,{'_id':4,'name':4})
print("The student who scored maximum socre in quiz:")
for i in y:
  print(i)
# Out:
# {'_id': {'type': 'homework'}, 'Max_score': 99.77237745070993}
# {'_id': {'type': 'exam'}, 'Max_score': 99.33685767140612}
# {'_id': {'type': 'quiz'}, 'Max_score': 99.80348240553108}
# The student who scored maximum socre in exam:
# {'_id': 136, 'name': 'Margart Vitello'}
# The student who scored maximum socre in homework:
# {'_id': 178, 'name': 'Whitley Fears'}
# The student who scored maximum socre in quiz:
# {'_id': 69, 'name': 'Cody Strouth'}

# %%
# TOTAL STUDENTS AND AVERAGE SCORES
L1 =[]
for x in records.find({},{"_id":0, "scores":1}):
  L1.append(x["scores"][0]["score"])
print(len(L1))
avg = sum(L1)/len(L1)
print(avg)
# Out:
# 200
# 48.67367075950174

# %%
## QUSTION 2: candidates getting above marks 40 and less than avg in type"exam" 
L2 = []
L3 = []
t = L3
for i in range(200):
  if(40 <= L1[i] <= int(avg)):
    L2.append(i)
for i in range(len(L2)):
  L3.append(K2[L2[i]])
for L3 in d:
    print(L3)
# Out:
# Denisha Cast
# Tressa Schwing
# Chad Rahe
# Jenise Mcguffie
# Cassi Heal
# Alix Sherrill
# Alica Pasley
# Harriett Velarde
# Rosana Vales
# Kayce Kenyon
# Demarcus Audette
# Aleida Elsass
# Wilburn Spiess
# Tamika Schildgen
# Terica Brugger
# Flora Duell
# Quincy Danaher
# Gwyneth Garling
# Mariela Sherer
# Gisela Levin
# Laureen Salomone
# Malisa Jeanes

# %%
##QUSTION 3: total number of pass and fails
# LIST OF STUDENTS WHO FAILED IN ALL IS CONSIDERED FAIL
for i in records.find({},{"name":1,"scores":1,"_id":0}):
    if all([i["scores"][0]["score"]<40 ,i["scores"][1]["score"]<40,i["scores"][2]["score"]<40]):
        records[" "].insert_one(i) 
        print("FAIL")
        print(i)
# LIST OF STUDENTS WHO HAS PASSED IN ALL IS CONSIDERED PASS
for i in records.find({},{"name":1,"scores":1,"_id":0}):
    if all([i["scores"][0]["score"]>40 ,i["scores"][1]["score"]>40,i["scores"][2]["score"]>40]):
        records[" "].insert_one(i) 
        print("PASS")
        print(i)
#LIST OF STUDENTS WHO SCORED ABOVE40% IS CONSIDERD PASS AND LESS THAN 40% IS CONSIDERED AS FAIL IN ALL CATAGORIES 
IF = [] 
IP = [] 
FAIL = [] 
PASS = [] 
l= PASS
o= FAIL
for i in range(200):
 if(L1[i] >=40):
    IP.append(i)
 elif(L1[i] < 40):
    IF.append(i)
for i in range(len(IP)):
    PASS.append(K2[IP[i]])
for i in range(len(IF)):
    FAIL.append(K2[IF[i]])
print("TOTAL STUDENTS:TOTAL STUDENTS PASSED:TOTAL STUDENTS FAILED",
      len(PASS)+len(FAIL),len(PASS),len(FAIL))
print("PASSED:STUDENTS WHO SCORED ABOVE 40% IN ALL MARKS COMBAINED")
for PASS in l:
    print(PASS)
print("FAILED:STUDENTS WHO SCORED BELOW 40% IN ALL MARKS COMBAINED")
for FAIL in o:
    print(FAIL)
# Out:
# FAIL
# {'name': 'aimee Zank', 'scores': [{'score': 1.463179736705023, 'type': 'exam'}, {'score': 11.78273309957772, 'type': 'quiz'}, {'score': 35.8740349954354, 'type': 'homework'}], '_id': ObjectId('62277397c27186aa212db2df')}
# PASS
# {'name': 'Denisha Cast', 'scores': [{'score': 45.61876862259409, 'type': 'exam'}, {'score': 98.35723209418343, 'type': 'quiz'}, {'score': 55.90835657173456, 'type': 'homework'}], '_id': ObjectId('62277398c27186aa212db2e0')}
# PASS
# {'name': 'Quincy Danaher', 'scores': [{'score': 54.29841278520669, 'type': 'exam'}, {'score': 85.61270164694737, 'type': 'quiz'}, {'score': 80.40732356118075, 'type': 'homework'}], '_id': ObjectId('62277398c27186aa212db2e1')}
# PASS
# {'name': 'Tressa Schwing', 'scores': [{'score': 42.17439799514388, 'type': 'exam'}, {'score': 71.99314840599558, 'type': 'quiz'}, {'score': 81.23972632069464, 'type': 'homework'}], '_id': ObjectId('62277398c27186aa212db2e2')}
# PASS
# ...

# %%
##QUSTION 4 : TOTAL MARK OF EACH SEGMENT
EXAM =[]
QUIZ = []
HOMEWORK = []
for x in records.find({},{"_id":0, "scores":1}):
    EXAM.append(x["scores"][0]["score"])
    QUIZ.append(x["scores"][1]["score"])
    HOMEWORK.append(x["scores"][2]["score"])
S1 = sum(EXAM)
S2 = sum(QUIZ)
S3 = sum(HOMEWORK)
print("TOTAL MARK OF EXAM IS ", S1)
print("TOTAL MARK OF QUIZ IS ", S2)
print("TOTAL MARK OF HOMEWORK IS ", S3)
# Out:
# TOTAL MARK OF EXAM IS  9734.734151900348
# TOTAL MARK OF QUIZ IS  9799.34463886051
# TOTAL MARK OF HOMEWORK IS  13563.739241322295

# %%
##QUSTION 4:TOTAL AVERAGE FOR EACH SEGMENT
EXAM =[]
QUIZ = []
HOMEWORK = []
for x in records.find({},{"_id":0, "scores":1}):
  EXAM.append(x["scores"][0]["score"])
  QUIZ.append(x["scores"][1]["score"])
  HOMEWORK.append(x["scores"][2]["score"])
avg1 = sum(EXAM)/len(EXAM)
avg2 = sum(QUIZ)/len(QUIZ)
avg3 = sum(HOMEWORK)/len(HOMEWORK)
print("AVERAGE SCORE FOR EXAM IS ",avg1)
print("AVERAGE SCORE FOR QUIZ IS " ,avg2)
print("AVERAGE SCORE FOR HOMEWORK IS ",avg3)
# Out:
# AVERAGE SCORE FOR EXAM IS  48.67367075950174
# AVERAGE SCORE FOR QUIZ IS  48.99672319430255
# AVERAGE SCORE FOR HOMEWORK IS  67.81869620661148

# %%
##QUSTION:5 WHO HAS ABOVE 40 IN EVERY SUBJECT AND BELOW AVERAGE 65
for i in records.find({},{"name":1,"scores":1,"_id":0}):
    if all([40<=i["scores"][0]["score"]<=65 ,40<=i["scores"][1]["score"]<=65,40<=i["scores"][2]["score"]<=65]):
        records[" "].insert_one(i) 
        print(i)
##NO RESULT TO DISPLAY IF AVERAGE IS LESS THAN 65
# Out:
# {'name': 'Rae Kohout', 'scores': [{'score': 63.86894250781692, 'type': 'exam'}, {'score': 55.81549538273672, 'type': 'quiz'}, {'score': 59.13566011309437, 'type': 'homework'}], '_id': ObjectId('6227739dc27186aa212db316')}

# %%
##QUSTION 6: LIST OF STUDENT WHO FAILED IN ALL
for i in records.find({},{"name":1,"scores":1,"_id":0}):
    if all([i["scores"][0]["score"]<40 ,i["scores"][1]["score"]<40,i["scores"][2]["score"]<40]):
        records[" "].insert_one(i) 
        print(i)
# Out:
# {'name': 'aimee Zank', 'scores': [{'score': 1.463179736705023, 'type': 'exam'}, {'score': 11.78273309957772, 'type': 'quiz'}, {'score': 35.8740349954354, 'type': 'homework'}], '_id': ObjectId('6227739ec27186aa212db317')}

# %%
##QUSTION 7:LIST OF STUDENTS WHO PASSED IN ALL
for i in records.find({},{"name":1,"scores":1,"_id":0}):
    if all([i["scores"][0]["score"]>40 ,i["scores"][1]["score"]>40,i["scores"][2]["score"]>40]):
        records[" "].insert_one(i) 
        print(i)
# Out:
# {'name': 'Denisha Cast', 'scores': [{'score': 45.61876862259409, 'type': 'exam'}, {'score': 98.35723209418343, 'type': 'quiz'}, {'score': 55.90835657173456, 'type': 'homework'}], '_id': ObjectId('6227739ec27186aa212db318')}
# {'name': 'Quincy Danaher', 'scores': [{'score': 54.29841278520669, 'type': 'exam'}, {'score': 85.61270164694737, 'type': 'quiz'}, {'score': 80.40732356118075, 'type': 'homework'}], '_id': ObjectId('6227739ec27186aa212db319')}
# {'name': 'Tressa Schwing', 'scores': [{'score': 42.17439799514388, 'type': 'exam'}, {'score': 71.99314840599558, 'type': 'quiz'}, {'score': 81.23972632069464, 'type': 'homework'}], '_id': ObjectId('6227739ec27186aa212db31a')}
# {'name': 'Eugene Magdaleno', 'scores': [{'score': 73.055900093666, 'type': 'exam'}, {'score': 79.85621560462026, 'type': 'quiz'}, {'score': 66.09143669040472, 'type': 'homework'}], '_id': ObjectId('6227739ec27186aa212db31b')}
# ...
